# %%
import polars as pl
from pathlib import Path

# Define project root
PROJECT_ROOT = Path("e:/miso-load-forecasting").resolve()
DATA_DIR = PROJECT_ROOT / "data"

# Verify directories exist
print(f"Project root: {PROJECT_ROOT}")
print(f"Data directory: {DATA_DIR}")
print(f"Contents: {[x.name for x in DATA_DIR.iterdir() if x.is_dir()]}")
# Out:
# Project root: E:\miso-load-forecasting
# Data directory: E:\miso-load-forecasting\data
# Contents: ['miso_load_actual', 'miso_load_forecast', 'weather_kmsp']

# %%
# Chunk 1: Load MISO Actual Load
actual_files = list((DATA_DIR / "miso_load_actual").rglob("*.parquet"))
actual_df = pl.scan_parquet(actual_files)

print(f"✓ MISO Actual: {actual_df.collect().shape[0]:,} rows")
# Out:
# ✓ MISO Actual: 145,752 rows

# %%
actual_df.head().collect()
# Out:
# shape: (5, 8)
# ┌─────────────────────┬─────────┬─────────┬─────────┬────────┬─────────┬───────────┬─────────┐
# │ Datetime            ┆ Lrz1    ┆ Lrz2_7  ┆ Lrz3_5  ┆ Lrz4   ┆ Lrz6    ┆ Lrz8_9_10 ┆ Miso    │
# │ ---                 ┆ ---     ┆ ---     ┆ ---     ┆ ---    ┆ ---     ┆ ---       ┆ ---     │
# │ datetime[ns]        ┆ f64     ┆ f64     ┆ f64     ┆ f64    ┆ f64     ┆ f64       ┆ f64     │
# ╞═════════════════════╪═════════╪═════════╪═════════╪════════╪═════════╪═══════════╪═════════╡
# │ 2025-10-07 23:00:00 ┆ 10906.3 ┆ 18657.6 ┆ 10472.8 ┆ 5415.6 ┆ 11089.2 ┆ 26312.9   ┆ 82854.4 │
# │ 2025-10-08 00:00:00 ┆ 11143.0 ┆ 18407.2 ┆ 10445.7 ┆ 5384.9 ┆ 10876.2 ┆ 25799.1   ┆ 82056.1 │
# │ 2025-10-08 01:00:00 ┆ 10996.6 ┆ 17617.9 ┆ 10206.5 ┆ 5267.6 ┆ 10369.0 ┆ 24855.7   ┆ 79313.3 │
# │ 2025-10-08 02:00:00 ┆ 10599.5 ┆ 16659.8 ┆ 9732.3  ┆ 5052.0 ┆ 9721.0  ┆ 23759.3   ┆ 75523.9 │
# │ 2025-10-08 03:00:00 ┆ 10064.8 ┆ 15719.9 ┆ 9234.7  ┆ 4711.8 ┆ 9107.1  ┆ 22366.6   ┆ 71204.9 │
# └─────────────────────┴─────────┴─────────┴─────────┴────────┴─────────┴───────────┴─────────┘
